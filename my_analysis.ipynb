# %% [markdown]
# <a href="https://colab.research.google.com/github/forfi4/introduction-to-python-2026-telhai-ps-8-ps8/blob/main/my_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv'
df = pd.read_csv(url)

df.to_csv('tips.csv', index=False)

df_clean = df.dropna()
print("First 5 rows of data:")
print(df_clean.head())

plt.figure(figsize=(8, 5))
plt.hist(df_clean['tip'], bins=10, color='skyblue', edgecolor='black')
plt.title('Distribution of Tips')
plt.xlabel('Tip Amount ($)')
plt.ylabel('Frequency')
plt.show()
# Out:
# First 5 rows of data:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
